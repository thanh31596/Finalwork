# %%
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium import webdriver
import time
import pandas as pd
import selenium
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains

# %%
path = r"C:/Users/Acer/chromedriver_win32/chromedriver.exe"
options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    #options.add_argument('headless')

    #Change the path to where chromedriver is in your home folder.
#Pre-defined Arrays and variables:
x=0
titles=[]
prices=[]
areas=[]
descriptions=[]
infors=[]



while x <2:
    x+=1
    driver = webdriver.Chrome(executable_path=path, options=options)
    wait = WebDriverWait(driver, 10)
    driver.set_window_size(1120, 1000)

    url = "https://batdongsan.com.vn/ban-nha-mat-pho-ha-noi/p"+str(x)
    driver.get(url)

    hbuttons= driver.find_elements_by_xpath('.//div[@clo="srpg"]') # to loop over all searches results
    
    i=0
    
    while i<20:
        hbuttons[i].click()
        #title      = driver.find_element_by_css_selector('h1.tile-product').text #ok as hell 
        #price      = driver.find_element_by_class_name('sp2').text #THIS ONE IS FINE AS FUCK
        #description= driver.find_element_by_class_name('des-product').text #ok
        try:
            area    = driver.find_element_by_tag_name('li:nth-child(2)').text
            
            #infor=driver.find_element_by_class_name('row-1:nth-child(3)').text #recheck later
        except NoSuchElementException:
            area=-1
            #infor = -1
                
        
        #titles.append(title)
        #prices.append(price)
        #descriptions.append(description)
        #infors.append(infor)
        areas.append(area)
        
        
        
        
        driver.back()
        hbuttons= driver.find_elements_by_xpath('.//div[@clo="srpg"]')
        i=i+1

# %%
areas
# Out:
# ['Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  '',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  '',
#  '',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  '',
#  '',
#  '',
#  'Trang chủ',
#  '',
#  '',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  'Trang chủ',
#  '',
#  'Trang chủ',
#  '',
#  'Trang chủ',
#  'Trang chủ',
#  '']

# %%
descriptions
# Out:
# ['Chính chủ bán nhà mặt đường 50m, Lê Trọng Tấn, Hà Đông, khu đô thị Văn Phú, diện tích đất 100.6m2, mặt tiền 5m, nhà 4 tầng xây thô, tổng diện tích 400m2.\nNhà mặt đường chính, rộng, thuận lợi kinh doanh buôn bán, cho thuê, làm nhà nghỉ, nhà trẻ, trường học, gara ô tô, đường để 20 chiếc ô tô cũng được.\nLiên hệ chính chủ - Mr Mạnh: 0912284*** (miễn trung gian).',
# ...

# %%
len(prices)
# Out:
# 40

# %%
df=pd.DataFrame()

# %%
df['title']=titles
df['price']=prices

# %%
df
# Out:
#                                                 title         price
# 0   BÁN NHÀ CHÍNH CHỦ MẶT ĐƯỜNG 50M LÊ TRỌNG TẤN, ...       13.6 tỷ
# 1   CHÍNH CHỦ BÁN BIỆT THỰ PHÁP CỔ FULL NỘI THẤT K...         27 tỷ
# 2   CHÍNH CHỦ CẦN BÁN NHÀ ĐẤT MẶT PHỐ LÊ TRỌNG TẤN...       11.2 tỷ
# 3   BẢNG HÀNG SHOPHOUSE LIỀN KỀ THE MANOR CENTRAL ...         16 tỷ
# 4   CHÍNH CHỦ CẦN BÁN NHÀ MP HOÀNG CẦU, LÔ GÓC. DT...         29 tỷ
# 5   HỒ TÂY. TRỊNH CÔNG SƠN. ĐẲNG CẤP HỒ TÂY. 100M....         34 tỷ
# 6   BÁN NHANH TRƯỚC TẾT NHÀ MẶT PHỐ NGUYỄN TRÃI - ...    Thỏa thuận
# 7   BÁN GẤP NHÀ MẶT PHỐ NGUYỄN KHANG - Ô TÔ TRÁNH ...    Thỏa thuận
# 8   BÁN NHÀ MẶT PHỐ MỖ LAO ĐANG CHO THUÊ 8 TRIỆU, ...       4.35 tỷ
# 9   CHÍNH CHỦ BÁN NHÀ 6 TẦNG XÂY MỚI 2020 MẶT PHỐ ...       11.9 tỷ
# 10  BÁN NHÀ 3 TẦNG DIỆN TÍCH ĐẤT 200M2, 268 TỐ HỮU...         29 tỷ
# 11  CHÍNH CHỦ BÁN TÒA VĂN PHÒNG 8 TẦNG MẶT PHỐ ĐẶN...         45 tỷ
# 12  CHÍNH CHỦ BÁN TÒA NHÀ MẶT PHỐ HOÀNG NGÂN, 145M...         58 tỷ
# ...

# %%
path = r"C:/Users/Acer/chromedriver_win32/chromedriver.exe"
options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    #options.add_argument('headless')

    #Change the path to where chromedriver is in your home folder.
#Pre-defined Arrays and variables:
x=0
titles=[]
prices=[]
areas=[]
descriptions=[]
infors=[]



while x <1:
    x+=1
    driver = webdriver.Chrome(executable_path=path, options=options)
    wait = WebDriverWait(driver, 10)
    driver.set_window_size(1120, 1000)

    url = "https://batdongsan.com.vn/ban-nha-mat-pho-ha-noi/p"+str(x)
    driver.get(url)

    hbuttons= driver.find_elements_by_xpath('.//div[@clo="srpg"]') # to loop over all searches results
    
    i=0
    
    while i<5:
        hbuttons[i].click()
        #title      = driver.find_element_by_css_selector('h1.tile-product').text #ok as hell 
        #price      = driver.find_element_by_class_name('sp2').text #THIS ONE IS FINE AS FUCK
        #description= driver.find_element_by_class_name('des-product').text #ok
        try:
            area    = driver.find_element_by_class_name('short-detail-2')
            
            #infor=driver.find_element_by_class_name('row-1:nth-child(3)').text #recheck later
        except NoSuchElementException:
            area=-1
            #infor = -1
                
        
        #titles.append(title)
        #prices.append(price)
        #descriptions.append(description)
        #infors.append(infor)
        areas.append(area)
        
        
        
        
        driver.back()
        hbuttons= driver.find_elements_by_xpath('.//div[@clo="srpg"]')
        i=i+1
